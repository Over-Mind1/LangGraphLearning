# %%
from langchain_core.messages import HumanMessage

from react_graph import react_graph
# Out:
# GEMINI_API_KEY environment variable is set.

# %%
response = react_graph.invoke(
    {
        "messages": [
            HumanMessage(
                content="What is the capital of France?"
            )
        ]
    }
)

response["messages"][-1].content
# Out:
# [{'type': 'text',
#   'text': 'The capital of France is Paris.',
#   'extras': {'signature': 'EjQKMgEMOdbHECuHOpPTjbuudjVOYB5B9gCUjmG5GyduxX8hHX4Zs8ubIHdhYWQImdsntjpJ'}}]

# %%
response = react_graph.invoke(
    {
        "messages": [
            HumanMessage(
                content="Get user data for user id 2"
            )
        ]
    }
)

print(
    response["messages"][-1].content
)
# Out:
# [{'type': 'text', 'text': 'The user data for user ID 2 is as follows:\n\n*   **Name:** Sara\n*   **Age:** 24\n*   **Role:** Designer\n*   **Email:** sara@example.com', 'extras': {'signature': 'EjQKMgEMOdbHXOD18ip4y6zzytDVjlUsOp1P7qiXF14njpNbSnNDjy0QDUj5N6HLDSELk6us'}}]

# %%
response
# Out:
# {'messages': [HumanMessage(content='Get user data for user id 2', additional_kwargs={}, response_metadata={}, id='3e77686d-6a6b-4044-b436-7f1455d1831b'),
#   AIMessage(content=[], additional_kwargs={'function_call': {'name': 'get_user_data', 'arguments': '{"user_id": "2"}'}, '__gemini_function_call_thought_signatures__': {'a40ed9f2-c2c2-47db-bbba-3bd1da265aa3': 'EjQKMgEMOdbHu0lB2/tM8wSySXDWkC0DtHg4RAZZG+N0sq0MfRwLExgjiQ67jF3vqNSBitEg'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e9cc3-b13e-7793-a752-61d6cde0c28e-0', tool_calls=[{'name': 'get_user_data', 'args': {'user_id': '2'}, 'id': 'a40ed9f2-c2c2-47db-bbba-3bd1da265aa3', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 107, 'output_tokens': 20, 'total_tokens': 127, 'input_token_details': {'cache_read': 0}}),
#   ToolMessage(content="{'name': 'Sara', 'age': 24, 'role': 'Designer', 'email': 'sara@example.com'}", name='get_user_data', id='80f38f7b-6139-4e47-ad0f-49eb4622fe40', tool_call_id='a40ed9f2-c2c2-47db-bbba-3bd1da265aa3'),
#   AIMessage(content=[{'type': 'text', 'text': 'The user data for user ID 2 is as follows:\n\n*   **Name:** Sara\n*   **Age:** 24\n*   **Role:** Designer\n*   **Email:** sara@example.com', 'extras': {'signature': 'EjQKMgEMOdbHXOD18ip4y6zzytDVjlUsOp1P7qiXF14njpNbSnNDjy0QDUj5N6HLDSELk6us'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e9cc3-b51a-7fe0-9090-1899e423359a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 172, 'output_tokens': 46, 'total_tokens': 218, 'input_token_details': {'cache_read': 0}})]}
